# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials #To access authorised Spotify data

# %%
#pip install spotipy #python module for querying spotify API

# %%
#step 1 get all names of artists into a list
#step 2 loop through artists and pull id
#step 3 loop through all ids and pull followers

# %%
#api credentials
client_id = '37d5c7b8360644bc8f785855408920ab'
client_secret = 'fc214853d2344ce0b6a24b20c540c6dd'

# %%
 #step 3 test #search query to get artist info using ID
client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager) #spotify object to access API

result = sp.artist('66CXWjxzNUsdJxJ2JdwvnR') #search query to get artist info/followers

# %%
#step 3 test
result['followers']['total'] #grabs total followers
# Out:
# 44903402

# %%
#step 2 test #get artist ID using artist name
client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager) #spotify object to access API
name = "Daft Punk" #chosen artist
result_id = sp.search(name) #search query to get artist ID
#result_id['tracks']['items'][0]['artists'][0]['id']

# %%
result_id['tracks']['items'][3]['artists'][0]['id']
# Out:
# '4tZwfgrHOc3mvqYlEYSvVi'

# %%
import pandas as pd
data=pd.read_csv('Spotify-2000.csv',index_col=0) #csv to gather artist names

# %%
data.head()
# Out:
#                         Title             Artist            Top Genre  Year  \
# Index
# 1                     Sunrise        Norah Jones      adult standards  2004
# 2                 Black Night        Deep Purple           album rock  2000
# 3              Clint Eastwood           Gorillaz  alternative hip hop  2001
# 4               The Pretender       Foo Fighters    alternative metal  2007
# 5      Waitin' On A Sunny Day  Bruce Springsteen         classic rock  2002
#
#        Beats Per Minute (BPM)  Energy  Danceability  Loudness (dB)  Liveness  \
# Index
# 1                         157      30            53            -14        11
# 2                         135      79            50            -11        17
# 3                         168      69            66             -9         7
# 4                         173      96            43             -4         3
# 5                         106      82            58             -5        10
#
# ...

# %%
data['Artist'].nunique()
# Out:
# 731

# %%
#step 1
artist_list=[name for name in data['Artist']]

# %%
len(artist_list)
# Out:
# 1994

# %%
unique_artist_list=list(set(artist_list))
len(unique_artist_list)
# Out:
# 731

# %%
unique_artist_list
# Out:
# ['Wham!',
#  'Gilbert Bécaud',
#  'Kensington',
#  'Chaka Khan',
#  'Counting Crows',
#  'Roxy Music',
#  'Gavin James',
#  'Florence + The Machine',
#  'Heart',
#  '3JS',
#  'John Denver',
#  'Suzan & Freek',
#  'Ram Jam',
#  'Kayak',
#  'Drs. P',
#  'Live',
#  'Peter Frampton',
#  'George Ezra',
#  'Dr. Hook',
#  'Gorki',
#  'Jimi Hendrix',
#  'Karin Bloemen',
#  'The Goo Goo Dolls',
#  'Steve Harley',
#  'Yann Tiersen',
#  'Electric Light Orchestra',
#  'Coolio',
#  'Gregory Porter',
#  'Mark Knopfler',
#  'Janis Joplin',
#  'The Weather Girls',
#  'Bram Vermeulen',
#  'Lee Towers',
#  'Frank Boeijen',
#  'Genesis',
#  'Alanis Morissette',
#  'Cher',
#  'Tavares',
#  'Liquido',
#  'Alice Cooper',
#  'Klein Orkest',
#  'Eels',
#  'Ede Staal',
#  'Skik',
#  'Santa Esmeralda',
#  'Kid Rock',
#  'Jewel',
#  'Gé Reinders',
#  'George Harrison',
#  'Franz Ferdinand',
#  'De Staat',
#  'Freddie Mercury',
#  'Ramones',
#  'Novastar',
#  'Derek & The Dominos',
#  'Bette Midler',
# ...

# %%
#script for step 2, get all ids and put into list for step 3


artist_count=0
for name in missing: #each artist
    id_results=sp.search(name)
    id_list5.append(id_results['tracks']['items'][8]['artists'][0]['id'])

# %%
len(id_list5)#fifth run
# Out:
# 518

# %%
len(id_list3) #third run
# Out:
# 95

# %%
len(id_list2) #second run
# Out:
# 731

# %%
len(id_list) #first run
# Out:
# 731

# %%
#test on data
REMID='66CXWjxzNUsdJxJ2JdwvnR'
if REMID in id_list:
    print('yes')
# Out:
# yes

# %%
#function to parse data
def parse_data(artist_dict):

    return artist_dict['name'], artist_dict['followers']['total']

# %%
columns = ['Artist','Total Followers']
df_followers=pd.DataFrame(columns=columns) #blank DF
df_followers.to_csv('Followers.csv')#blank csv
def data_save(parsed_results, csv_filename):
    #reads in blank csv #creates new DF for each page of results
    existing=pd.read_csv(csv_filename,index_col=0)
    new = pd.DataFrame(parsed_results,columns=columns)
    df = pd.concat([existing,new])
    df.to_csv(csv_filename)

# %%
#step 3 script, use IDs to pull follower count for all artists



follower_list5 = []
for ele in id_list5: 
   
    #make API call with the new id 
    artist_results = sp.artist(ele)
    
    #function to parse results
    parsed_data = parse_data(artist_results)
    follower_list5.append(parsed_data)
    
    # function to insert parsed results into the CSV 
    #data_save(follower_list, 'Followers.csv')

# %%
#follower_list5

# %%
#follower_list4

# %%
#follower_list3

# %%
#follower_list2

# %%
follower_list5=pd.DataFrame(follower_list5,columns=columns)

# %%
#complete_df=data.merge(all_followers3[['Artist','Total Followers']],on=['Artist'],how='left')#follower_list_df,on='Artist',how='left')

# %%
#complete_df.shape
# Out:
# (4088, 15)

# %%
data.shape
# Out:
# (1994, 14)

# %%
follower_list_df.shape
# Out:
# (731, 2)

# %%
complete_df.isnull().sum()
# Out:
# Title                      0
# Artist                     0
# Top Genre                  0
# Year                       0
# Beats Per Minute (BPM)     0
# Energy                     0
# Danceability               0
# Loudness (dB)              0
# Liveness                   0
# Valence                    0
# Length (Duration)          0
# Acousticness               0
# Speechiness                0
# Popularity                 0
# Total Followers           94
# dtype: int64

# %%
#complete_df.to_csv('test.csv')

# %%
test=complete_df.drop_duplicates()

# %%
test.isnull().sum()
# Out:
# Title                      0
# Artist                     0
# Top Genre                  0
# Year                       0
# Beats Per Minute (BPM)     0
# Energy                     0
# Danceability               0
# Loudness (dB)              0
# Liveness                   0
# Valence                    0
# Length (Duration)          0
# Acousticness               0
# Speechiness                0
# Popularity                 0
# Total Followers           94
# dtype: int64

# %%
#to see missing artists 
test.sort_values(by='Total Followers',ascending=True).tail(94)['Artist'].unique()
# Out:
# array(['City To City', 'BLØF', 'Blue', 'Armand', 'IOS',
#        'The Black Eyed Peas', 'Fish', 'Golden Earrings', 'Gossip',
#        'JOHAN', 'The Scene', 'Kayak', 'Focus', 'Kane', 'Mud', 'Faithless',
#        'Abel', 'Gorki', 'Live', 'White Lies', 'Kensington', 'Drs. P',
#        'Air', 'Waylon', 'Tones and I', 'Yes', 'America', 'Sweet', 'Heart',
#        'Lucifer', 'CHIC', 'KISS', 'Madness', 'BAP', 'Nits', 'The The',
#        'Japan', 'Black', 'Cher', 'SNAP!', 'Valensia', 'Therapy?', 'Skik',
#        'Hero', 'Venice', 'Melanie'], dtype=object)

# %%
import pandas as pd

# %%
#followers1_df=pd.read_csv('followers2.csv')

# %%
#followers1_df.drop(columns='Unnamed: 0',inplace=True)

# %%
#followers1_df

# %%
#all_followers=pd.concat([followers1_df,follower_list2])

# %%
#all_followers.drop_duplicates()

# %%
#test 
band='City to City'
if band in list(all_followers['Artist']):
    print('true')

# %%
#missing artists follower count
len(test.sort_values(by='Total Followers',ascending=False).tail(94)['Artist'].unique())
# Out:
# 46

# %%
all_followers3=pd.concat([all_followers2,follower_list5]) #append new followers here

# %%
test #complete data
# Out:
#                        Title                    Artist            Top Genre  \
# 0                    Sunrise               Norah Jones      adult standards
# 2                Black Night               Deep Purple           album rock
# 4             Clint Eastwood                  Gorillaz  alternative hip hop
# 15             The Pretender              Foo Fighters    alternative metal
# 17    Waitin' On A Sunny Day         Bruce Springsteen         classic rock
# ...                      ...                       ...                  ...
# 4078        Heartbreak Hotel             Elvis Presley      adult standards
# 4080               Hound Dog             Elvis Presley      adult standards
# 4082         Johnny B. Goode               Chuck Berry           blues rock
# 4084               Take Five  The Dave Brubeck Quartet                bebop
# 4086          Blueberry Hill               Fats Domino      adult standards
#
# ...

# %%
test.to_csv('spotify_all_data.csv')

# %%
missing2=['City To City', 'BLØF', 'Blue', 'Armand', 'IOS',
       'The Black Eyed Peas', 'Fish', 'Golden Earrings', 'Gossip',
       'JOHAN', 'The Scene', 'Kayak', 'Focus', 'Kane', 'Mud', 'Faithless',
       'Abel', 'Gorki', 'Live', 'White Lies', 'Kensington', 'Drs. P',
       'Air', 'Waylon', 'Tones and I', 'Yes', 'America', 'Sweet', 'Heart',
       'Lucifer', 'CHIC', 'KISS', 'Madness', 'BAP', 'Nits', 'The The',
       'Japan', 'Black', 'Cher', 'SNAP!', 'Valensia', 'Therapy?', 'Skik',
       'Hero', 'Venice', 'Melanie']

# %%
Blue=test[test['Artist']=='Blue']

# %%
all_data=pd.read_csv('spotify_all_data.csv')

# %%
all_data.drop(columns='Unnamed: 0',inplace=True)

# %%
all_data2=all_data

# %%
pd.set_option('display.max_rows', 50)
all_data2[all_data2.isnull().any(axis=1)]
# Out:
#                                       Title        Artist  \
# 5     The Road Ahead (Miles Of The Unknown)  City To City
# 24                      Dichterbij Dan Ooit          BLØF
# 51                           Dansen Aan Zee          BLØF
# 83       Sorry Seems To Be The Hardest Word          Blue
# 85                    Aanzoek Zonder Ringen          BLØF
# ...                                     ...           ...
# 1801               Harder Dan Ik Hebben Kan          BLØF
# 1810                        The Family Tree        Venice
# 1814                      The Dolphin's Cry          Live
# 1821                       Run To The Water          Live
# 1969                       Beautiful People       Melanie
#
#                  Top Genre  Year  Beats Per Minute (BPM)  Energy  \
# 5     alternative pop rock  2004                      99      46
# 24               dutch pop  2002                     112      74
# 51               dutch pop  2000                     194      43
# ...
